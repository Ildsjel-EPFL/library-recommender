# %% [markdown]
# # Imports

# %%
from pathlib import Path
import numpy as np
import numpy.typing as npt
import pandas as pd
import sklearn
from sklearn.metrics.pairwise import cosine_similarity
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data loading and Splitting

# %%
interactions = pd.read_csv(Path.cwd().parent/"data"/"interactions_train.csv")
items = pd.read_csv(Path.cwd().parent/"data"/"items.csv")

# %%
interactions
# Out:
#           u      i             t
# 0      4456   8581  1.687541e+09
# 1       142   1964  1.679585e+09
# 2       362   3705  1.706872e+09
# 3      1809  11317  1.673533e+09
# 4      4384   1323  1.681402e+09
# ...     ...    ...           ...
# 87042   924   8171  1.699284e+09
# 87043  1106   9009  1.699872e+09
# 87044  5207  13400  1.683627e+09
# 87045   698   5779  1.686667e+09
# 87046  3111   7988  1.681743e+09
#
# [87047 rows x 3 columns]

# %%
unique_items = interactions.i.unique().tolist()
unique_items.sort()

id_in_order = [unique_items.index(i) for i in interactions["i"]]
interactions["i in order"] = id_in_order

interactions
# Out:
#           u      i             t  i in order
# 0      4456   8581  1.687541e+09        8509
# 1       142   1964  1.679585e+09        1944
# 2       362   3705  1.706872e+09        3677
# 3      1809  11317  1.673533e+09       11216
# 4      4384   1323  1.681402e+09        1306
# ...     ...    ...           ...         ...
# 87042   924   8171  1.699284e+09        8103
# 87043  1106   9009  1.699872e+09        8931
# 87044  5207  13400  1.683627e+09       13282
# 87045   698   5779  1.686667e+09        5735
# 87046  3111   7988  1.681743e+09        7921
#
# [87047 rows x 4 columns]

# %%
n_users = interactions["u"].nunique()
n_items = interactions["i"].nunique()
print(f"Number of users: {n_users}, number of items: {n_items}, number of interactions: {len(interactions)}")
# Out:
# Number of users: 7838, number of items: 15109, number of interactions: 87047

# %%
ref = 0
inter_list = interactions["i"].unique().tolist()
print(f"Minimum item ID: {min(inter_list)}, Maximum item ID: {max(inter_list)}")
inter_list.sort()
for i in inter_list:
    if i != ref:
        print(f"Item {i} is NOT in the interactions dataset.")
        ref = i
    ref+=1
# Out:
# Minimum item ID: 0, Maximum item ID: 15290
# Item 96 is NOT in the interactions dataset.
# Item 211 is NOT in the interactions dataset.
# Item 514 is NOT in the interactions dataset.
# Item 516 is NOT in the interactions dataset.
# Item 518 is NOT in the interactions dataset.
# Item 522 is NOT in the interactions dataset.
# Item 525 is NOT in the interactions dataset.
# Item 648 is NOT in the interactions dataset.
# Item 836 is NOT in the interactions dataset.
# Item 841 is NOT in the interactions dataset.
# Item 846 is NOT in the interactions dataset.
# Item 851 is NOT in the interactions dataset.
# Item 893 is NOT in the interactions dataset.
# Item 1259 is NOT in the interactions dataset.
# Item 1460 is NOT in the interactions dataset.
# Item 1652 is NOT in the interactions dataset.
# Item 1692 is NOT in the interactions dataset.
# Item 2362 is NOT in the interactions dataset.
# Item 2569 is NOT in the interactions dataset.
# Item 2607 is NOT in the interactions dataset.
# Item 2661 is NOT in the interactions dataset.
# Item 2942 is NOT in the interactions dataset.
# Item 3185 is NOT in the interactions dataset.
# Item 3213 is NOT in the interactions dataset.
# Item 3265 is NOT in the interactions dataset.
# Item 3789 is NOT in the interactions dataset.
# Item 3798 is NOT in the interactions dataset.
# Item 4011 is NOT in the interactions dataset.
# Item 4265 is NOT in the interactions dataset.
# Item 4267 is NOT in the interactions dataset.
# Item 4269 is NOT in the interactions dataset.
# Item 4272 is NOT in the interactions dataset.
# Item 4437 is NOT in the interactions dataset.
# Item 4507 is NOT in the interactions dataset.
# Item 4510 is NOT in the interactions dataset.
# Item 4512 is NOT in the interactions dataset.
# Item 4593 is NOT in the interactions dataset.
# Item 4764 is NOT in the interactions dataset.
# Item 4843 is NOT in the interactions dataset.
# Item 5094 is NOT in the interactions dataset.
# Item 5742 is NOT in the interactions dataset.
# Item 5996 is NOT in the interactions dataset.
# Item 6038 is NOT in the interactions dataset.
# Item 6079 is NOT in the interactions dataset.
# Item 6180 is NOT in the interactions dataset.
# Item 6574 is NOT in the interactions dataset.
# Item 6684 is NOT in the interactions dataset.
# Item 6865 is NOT in the interactions dataset.
# Item 6925 is NOT in the interactions dataset.
# Item 7149 is NOT in the interactions dataset.
# Item 7282 is NOT in the interactions dataset.
# Item 7384 is NOT in the interactions dataset.
# Item 7425 is NOT in the interactions dataset.
# Item 7465 is NOT in the interactions dataset.
# Item 7469 is NOT in the interactions dataset.
# Item 7721 is NOT in the interactions dataset.
# Item 7767 is NOT in the interactions dataset.
# Item 7780 is NOT in the interactions dataset.
# Item 7840 is NOT in the interactions dataset.
# Item 7898 is NOT in the interactions dataset.
# Item 7925 is NOT in the interactions dataset.
# Item 7933 is NOT in the interactions dataset.
# Item 7976 is NOT in the interactions dataset.
# Item 7980 is NOT in the interactions dataset.
# Item 8044 is NOT in the interactions dataset.
# Item 8203 is NOT in the interactions dataset.
# Item 8266 is NOT in the interactions dataset.
# Item 8309 is NOT in the interactions dataset.
# Item 8536 is NOT in the interactions dataset.
# Item 8721 is NOT in the interactions dataset.
# Item 8790 is NOT in the interactions dataset.
# Item 8863 is NOT in the interactions dataset.
# Item 8868 is NOT in the interactions dataset.
# Item 8881 is NOT in the interactions dataset.
# Item 8884 is NOT in the interactions dataset.
# Item 9032 is NOT in the interactions dataset.
# Item 9037 is NOT in the interactions dataset.
# Item 9058 is NOT in the interactions dataset.
# Item 9071 is NOT in the interactions dataset.
# Item 9121 is NOT in the interactions dataset.
# Item 9171 is NOT in the interactions dataset.
# Item 9363 is NOT in the interactions dataset.
# Item 9457 is NOT in the interactions dataset.
# Item 9542 is NOT in the interactions dataset.
# Item 9609 is NOT in the interactions dataset.
# Item 9832 is NOT in the interactions dataset.
# Item 10041 is NOT in the interactions dataset.
# Item 10269 is NOT in the interactions dataset.
# Item 10714 is NOT in the interactions dataset.
# Item 10825 is NOT in the interactions dataset.
# Item 10832 is NOT in the interactions dataset.
# Item 10904 is NOT in the interactions dataset.
# Item 10934 is NOT in the interactions dataset.
# Item 11019 is NOT in the interactions dataset.
# Item 11063 is NOT in the interactions dataset.
# Item 11128 is NOT in the interactions dataset.
# Item 11221 is NOT in the interactions dataset.
# Item 11291 is NOT in the interactions dataset.
# Item 11344 is NOT in the interactions dataset.
# Item 11464 is NOT in the interactions dataset.
# Item 11967 is NOT in the interactions dataset.
# Item 12271 is NOT in the interactions dataset.
# Item 12354 is NOT in the interactions dataset.
# Item 12365 is NOT in the interactions dataset.
# Item 12382 is NOT in the interactions dataset.
# Item 12408 is NOT in the interactions dataset.
# Item 12489 is NOT in the interactions dataset.
# Item 12632 is NOT in the interactions dataset.
# Item 13044 is NOT in the interactions dataset.
# Item 13116 is NOT in the interactions dataset.
# Item 13137 is NOT in the interactions dataset.
# Item 13141 is NOT in the interactions dataset.
# Item 13276 is NOT in the interactions dataset.
# Item 13323 is NOT in the interactions dataset.
# Item 13342 is NOT in the interactions dataset.
# Item 13602 is NOT in the interactions dataset.
# Item 13634 is NOT in the interactions dataset.
# Item 13994 is NOT in the interactions dataset.
# Item 14031 is NOT in the interactions dataset.
# Item 14052 is NOT in the interactions dataset.
# Item 14079 is NOT in the interactions dataset.
# Item 14104 is NOT in the interactions dataset.
# Item 14180 is NOT in the interactions dataset.
# Item 14202 is NOT in the interactions dataset.
# Item 14257 is NOT in the interactions dataset.
# Item 14264 is NOT in the interactions dataset.
# Item 14301 is NOT in the interactions dataset.
# Item 14344 is NOT in the interactions dataset.
# Item 14347 is NOT in the interactions dataset.
# Item 14361 is NOT in the interactions dataset.
# Item 14398 is NOT in the interactions dataset.
# Item 14404 is NOT in the interactions dataset.
# Item 14422 is NOT in the interactions dataset.
# Item 14434 is NOT in the interactions dataset.
# Item 14475 is NOT in the interactions dataset.
# Item 14550 is NOT in the interactions dataset.
# Item 14569 is NOT in the interactions dataset.
# Item 14635 is NOT in the interactions dataset.
# Item 14779 is NOT in the interactions dataset.
# Item 14787 is NOT in the interactions dataset.
# Item 14829 is NOT in the interactions dataset.
# Item 14843 is NOT in the interactions dataset.
# Item 14877 is NOT in the interactions dataset.
# Item 14896 is NOT in the interactions dataset.
# Item 14903 is NOT in the interactions dataset.
# Item 14923 is NOT in the interactions dataset.
# Item 14936 is NOT in the interactions dataset.
# Item 14946 is NOT in the interactions dataset.
# Item 14967 is NOT in the interactions dataset.
# Item 14995 is NOT in the interactions dataset.
# Item 15000 is NOT in the interactions dataset.
# Item 15005 is NOT in the interactions dataset.
# Item 15038 is NOT in the interactions dataset.
# Item 15072 is NOT in the interactions dataset.
# Item 15081 is NOT in the interactions dataset.
# Item 15088 is NOT in the interactions dataset.
# Item 15104 is NOT in the interactions dataset.
# Item 15112 is NOT in the interactions dataset.
# Item 15115 is NOT in the interactions dataset.
# Item 15131 is NOT in the interactions dataset.
# Item 15152 is NOT in the interactions dataset.
# Item 15159 is NOT in the interactions dataset.
# Item 15161 is NOT in the interactions dataset.
# Item 15184 is NOT in the interactions dataset.
# Item 15202 is NOT in the interactions dataset.
# Item 15222 is NOT in the interactions dataset.
# Item 15238 is NOT in the interactions dataset.
# Item 15240 is NOT in the interactions dataset.
# Item 15252 is NOT in the interactions dataset.
# Item 15257 is NOT in the interactions dataset.
# Item 15267 is NOT in the interactions dataset.
# Item 15276 is NOT in the interactions dataset.
# Item 15287 is NOT in the interactions dataset.

# %%
ref = 0
user_list = interactions["u"].unique().tolist()
print(f"Minimum user ID: {min(user_list)}, Maximum user ID: {max(user_list)}")
user_list.sort()
for i in user_list:
    if i != ref:
        print(f"User {i} is NOT in the interactions dataset.")
        ref = i
    ref+=1
# Out:
# Minimum user ID: 0, Maximum user ID: 7837

# %%
interactions.i.max()
# Out:
# np.int64(15290)

# %%
interactions = interactions.sort_values(["u", "t"])
interactions
# Out:
#           u     i             t  i in order
# 21035     0     0  1.680191e+09           0
# 28842     0     1  1.680783e+09           1
# 3958      0     2  1.680801e+09           2
# 29592     0     3  1.683715e+09           3
# 6371      0     3  1.683715e+09           3
# ...     ...   ...           ...         ...
# 74604  7836  3471  1.728644e+09        3443
# 69092  7836  3471  1.728644e+09        3443
# 51684  7837  2191  1.728735e+09        2171
# 76172  7837    88  1.728735e+09          88
# 30565  7837  2209  1.728735e+09        2189
#
# [87047 rows x 4 columns]

# %%
interactions["pct_rank"] = interactions.groupby("u")["t"].rank(pct=True, method='dense')
interactions.reset_index(inplace=True, drop=True)
interactions
# Out:
#           u     i             t  i in order  pct_rank
# 0         0     0  1.680191e+09           0  0.040000
# 1         0     1  1.680783e+09           1  0.080000
# 2         0     2  1.680801e+09           2  0.120000
# 3         0     3  1.683715e+09           3  0.160000
# 4         0     3  1.683715e+09           3  0.200000
# ...     ...   ...           ...         ...       ...
# 87042  7836  3471  1.728644e+09        3443  0.666667
# 87043  7836  3471  1.728644e+09        3443  1.000000
# 87044  7837  2191  1.728735e+09        2171  0.333333
# 87045  7837    88  1.728735e+09          88  0.666667
# 87046  7837  2209  1.728735e+09        2189  1.000000
#
# [87047 rows x 5 columns]

# %%
train_data = interactions[interactions["pct_rank"] < 0.8]
test_data = interactions[interactions["pct_rank"] >= 0.8]

print("Training set size:", train_data.shape[0])
print("Testing set size:", test_data.shape[0])
# Out:
# Training set size: 65419
# Testing set size: 21628

# %% [markdown]
# # User-Item Matrices

# %%
def create_data_mtx(data : pd.DataFrame, n_users: int, n_items: int) -> npt.NDArray[np.float64]:
    """
    Create a user-item interaction matrix from the given data.

    :param data: A DataFrame containing user-item interactions with columns "u" for user IDs and "i" for item IDs.
    :type data: pd.DataFrame
    :param n_users: The number of users.
    :type n_users: int
    :param n_items: The number of items.
    :type n_items: int
    :return: A user-item interaction matrix.
    :rtype: npt.NDArray[np.float64]
    """
    data_mtx = np.zeros((n_users, n_items))    # Ensure the matrix can accommodate all item IDs
    data_mtx[data["u"].values, data["i in order"].values] = 1
    # data_mtx = np.zeros((n_users, max(interactions.i.unique())+1))
    # data_mtx[data["u"].values, data["i"].values] = 1
    return data_mtx

train_data_mtx = create_data_mtx(train_data, n_users, n_items)
test_data_mtx = create_data_mtx(test_data, n_users, n_items)
print("Number of interactions in training set:", np.sum(train_data_mtx))
print("Number of interactions in test set:", np.sum(test_data_mtx))
# Out:
# Number of interactions in training set: 49689.0
# Number of interactions in test set: 19409.0

# %% [markdown]
# # Item-to-Item

# %%
item_similarity = cosine_similarity(train_data_mtx.T)
item_similarity.shape
# Out:
# (15109, 15109)

# %%
def item_based_predict(interactions : pd.DataFrame, similarity : npt.NDArray[np.float64], epsilon=1e-9):
    """
    Predicts user-item interactions based on item-item similarity.

    :param interactions: The user-item interaction matrix.
    :type interactions: pd.DataFrame
    :param similarity: The item-item similarity matrix.
    :type similarity: npt.NDArray[np.float64]
    :param epsilon: Small constant added to the denominator to avoid division by zero.
    :type epsilon: float
    :return: The predicted interaction scores for each user-item pair.
    :rtype: npt.NDArray[np.float64]
    """
    # np.dot does the matrix multiplication. Here we are calculating the
    # weighted sum of interactions based on item similarity
    pred = similarity.dot(interactions.T) / (similarity.sum(axis=1)[:, np.newaxis] + epsilon)
    return pred.T  # Transpose to get users as rows and items as columns

item_prediction = item_based_predict(train_data_mtx, item_similarity)
item_prediction.shape
# Out:
# (7838, 15109)

# %% [markdown]
# # User-to-User

# %%
user_similarity = cosine_similarity(train_data_mtx)
user_similarity.shape
# Out:
# (7838, 7838)

# %%
def user_based_predict(interactions, similarity, epsilon=1e-9):
    """
    Predicts user-item interactions based on user-user similarity.
    
    :param interactions: The user-item interaction matrix.
    :type interactions: npt.NDArray[np.float64]
    :param similarity: The user-user similarity matrix.
    :type similarity: npt.NDArray[np.float64]
    :param epsilon: Small constant added to the denominator to avoid division by zero.
    :type epsilon: float
    :return: The predicted interaction scores for each user-item pair.
    :rtype: npt.NDArray[np.float64]
    """
    # Calculate the weighted sum of interactions based on user similarity
    pred = similarity.dot(interactions) / (np.abs(similarity).sum(axis=1)[:, np.newaxis] + epsilon)
    return pred

# Calculate the user-based predictions for positive interactions
user_prediction = user_based_predict(train_data_mtx, user_similarity)
user_prediction.shape
# Out:
# (7838, 15109)

# %% [markdown]
# # Evaluation

# %%
def precision_recall_at_k(prediction, ground_truth, k=10):
    """
    Calculates Precision@K and Recall@K for top-K recommendations.

    :param prediction: The predicted interaction matrix with scores.
    :type prediction: npt.NDArray[np.float64]
    :param ground_truth: The ground truth interaction matrix (binary).
    :type ground_truth: npt.NDArray[np.float64]
    :param k: Number of top recommendations to consider.
    :type k: int
    :return: The average precision@K and recall@K over all users.
    :rtype: tuple[float, float]
    """
    num_users = prediction.shape[0]
    precision_at_k, recall_at_k = 0, 0

    for user in range(num_users):
        top_k_items = np.argsort(prediction[user, :])[-k:]
        relevant_items_in_top_k = np.isin(top_k_items, np.where(ground_truth[user, :] == 1)[0]).sum()
        total_relevant_items = ground_truth[user, :].sum()
        precision_at_k += relevant_items_in_top_k / k
        recall_at_k += relevant_items_in_top_k / total_relevant_items if total_relevant_items > 0 else 0
    precision_at_k /= num_users
    recall_at_k /= num_users
    
    return precision_at_k, recall_at_k

precision_user_k, recall_user_k = precision_recall_at_k(user_prediction, test_data_mtx, k=10)
precision_item_k, recall_item_k = precision_recall_at_k(item_prediction, test_data_mtx, k=10)

print('User-based CF Precision@K:', precision_user_k)
print('User-based CF Recall@K:', recall_user_k)
print('Item-based CF Precision@K:', precision_item_k)
print('Item-based CF Recall@K:', recall_item_k)
# Out:
# User-based CF Precision@K: 0.056557795355960915
# User-based CF Recall@K: 0.29074409391720035
# Item-based CF Precision@K: 0.055702985455476146
# Item-based CF Recall@K: 0.26416329763269525

# %%
def precision_recall_at_k(prediction, ground_truth, k=10):
    """
    Calculates Precision@K and Recall@K for top-K recommendations.

    :param prediction: The predicted interaction matrix with scores.
    :type prediction: npt.NDArray[np.float64]
    :param ground_truth: The ground truth interaction matrix (binary).
    :type ground_truth: npt.NDArray[np.float64]
    :param k: Number of top recommendations to consider.
    :type k: int
    :return: The average precision@K and recall@K over all users.
    :rtype: tuple[float, float]
    """
    num_users = prediction.shape[0]
    precision_at_k, recall_at_k = 0, 0

    for user in range(num_users):
        top_k_items = np.argsort(prediction[user, :])[-k:]
        relevant_items_in_top_k = np.isin(top_k_items, np.where(ground_truth[user, :] == 1)[0]).sum()
        total_relevant_items = ground_truth[user, :].sum()
        precision_at_k += relevant_items_in_top_k / k
        recall_at_k += relevant_items_in_top_k / total_relevant_items if total_relevant_items > 0 else 0
    precision_at_k /= num_users
    recall_at_k /= num_users
    
    return precision_at_k, recall_at_k

precision_user_k, recall_user_k = precision_recall_at_k(user_prediction, test_data_mtx, k=10)
precision_item_k, recall_item_k = precision_recall_at_k(item_prediction, test_data_mtx, k=10)

print('User-based CF Precision@K:', precision_user_k)
print('User-based CF Recall@K:', recall_user_k)
print('Item-based CF Precision@K:', precision_item_k)
print('Item-based CF Recall@K:', recall_item_k)
# Out:
# User-based CF Precision@K: 0.056557795355960915
# User-based CF Recall@K: 0.29074409391720035
# Item-based CF Precision@K: 0.055702985455476146
# Item-based CF Recall@K: 0.26416329763269525

# %% [markdown]
# #  Build submission

# %%
sample_submission = pd.read_csv(Path.cwd().parent/"data"/"sample_submission.csv")
submission_user = pd.DataFrame()
submission_user["user_id"] = sample_submission["user_id"]
submission_item = submission_user.copy()
predictions_user = []
precision_item = []
for u in submission_user["user_id"]:
    top_10_items = np.argsort(user_prediction[u, :])[-10:][::-1]
    top_10_users = np.argsort(item_prediction[u, :])[-10:][::-1]
    predictions_user.append(" ".join(map(str, top_10_users)))
    precision_item.append(" ".join(map(str, top_10_items)))
submission_user["recommendation"] = predictions_user
submission_item["recommendation"] = precision_item
submission_user.to_csv(Path.cwd().parent/"submissions"/"submission_user_v2.csv", index=False)
submission_item.to_csv(Path.cwd().parent/"submissions"/"submission_item_v2.csv", index=False)

# %%
full_data_mtx = create_data_mtx(interactions, n_users, n_items)
print("Number of interactions in full set:", np.sum(full_data_mtx))

# 2. Recompute Item-Item similarities and predictions on the full dataset
print("Computing full Item-based predictions...")
full_item_similarity = cosine_similarity(full_data_mtx.T)
full_item_prediction = item_based_predict(full_data_mtx, full_item_similarity)

# 3. Recompute User-User similarities and predictions on the full dataset
print("Computing full User-based predictions...")
full_user_similarity = cosine_similarity(full_data_mtx)
full_user_prediction = user_based_predict(full_data_mtx, full_user_similarity)

# 4. Build the final submission using the completely retrained predictions
sample_submission = pd.read_csv(Path.cwd().parent/"data"/"sample_submission.csv")

submission_user = pd.DataFrame()
submission_user["user_id"] = sample_submission["user_id"]

submission_item = pd.DataFrame()
submission_item["user_id"] = sample_submission["user_id"]

predictions_user = []
predictions_item = []

for u in submission_user["user_id"]:
    # We want to recommend items the user HAS NOT interacted with yet.
    # To do this cleanly, we can set the scores of already interacted items to a large negative number
    # (or simply 0 if your scores are strictly positive) before taking the top 10.
    
    # Copy the scores for the user
    u_scores_user_cf = full_user_prediction[u, :].copy()
    u_scores_item_cf = full_item_prediction[u, :].copy()
    
    # Zero out items the user has already interacted with (so we don't recommend a read book)
    # already_read_indices = np.where(full_data_mtx[u, :] > 0)[0]
    # u_scores_user_cf[already_read_indices] = -np.inf
    # u_scores_item_cf[already_read_indices] = -np.inf
    
    # Get top 10 items
    # top_10_users_cf = np.argsort(u_scores_user_cf)[-10:][::-1] # [::-1] ensures descending order
    # top_10_items_cf = np.argsort(u_scores_item_cf)[-10:][::-1]
    top_10_users_cf = np.argsort(u_scores_user_cf)[-10:]
    top_10_items_cf = np.argsort(u_scores_item_cf)[-10:]

    temp_u = []
    temp_i = []
    i_in_order = interactions["i in order"].to_list()
    for i in top_10_users_cf:
        temp_u.append(interactions["i"][i_in_order.index(i)])
    top_10_users_cf = np.array(temp_u)
    for i in top_10_items_cf:
        temp_i.append(interactions["i"][i_in_order.index(i)])
    top_10_items_cf = np.array(temp_i)
    
    predictions_user.append(" ".join(map(str, top_10_users_cf)))
    predictions_item.append(" ".join(map(str, top_10_items_cf)))

submission_user["recommendation"] = predictions_user
submission_item["recommendation"] = predictions_item

# Save files
submission_user.to_csv(Path.cwd().parent/"submissions"/"submission_user_full_unfiltered_v3.csv", index=False)
submission_item.to_csv(Path.cwd().parent/"submissions"/"submission_item_full_unfiltered_v3.csv", index=False)
# Out:
# Number of interactions in full set: 64003.0
# Computing full Item-based predictions...
# Computing full User-based predictions...

# %%
# Get the row (user) and column (item) indices of actual interactions in the test set
test_user_idx, test_item_idx = np.nonzero(test_data_mtx)

best_alpha = 0
best_score = 0 # Higher is better

print("Starting Grid Search for alpha...")
# Test alpha values from 0.0 to 1.0 in steps of 0.1
for alpha in np.linspace(0.2, 0.3, 11):
    # Combine predictions
    hybrid_pred = (alpha * item_prediction) + ((1 - alpha) * user_prediction)
    
    # Calculate the average predicted score for actual positive interactions in the test set
    precision_k, recall_k = precision_recall_at_k(hybrid_pred, test_data_mtx, k=10)
    
    print(f"Alpha: {alpha} | Precision@10: {precision_k:.4f} | Recall@10: {recall_k:.4f}")
    
#     if score > best_score:
#         best_score = score
#         best_alpha = alpha

# print(f"\nBest Alpha found: {best_alpha:.1f}")

# Create your final optimized predictions (useful for offline metrics or Kaggle)
final_hybrid_predictions = (best_alpha * item_prediction) + ((1 - best_alpha) * user_prediction)
# Out:
# Starting Grid Search for alpha...
# Alpha: 0.2 | Precision@10: 0.0610 | Recall@10: 0.2951
# Alpha: 0.21000000000000002 | Precision@10: 0.0613 | Recall@10: 0.2954
# Alpha: 0.22 | Precision@10: 0.0613 | Recall@10: 0.2955
# Alpha: 0.23 | Precision@10: 0.0613 | Recall@10: 0.2955
# Alpha: 0.24 | Precision@10: 0.0613 | Recall@10: 0.2956
# Alpha: 0.25 | Precision@10: 0.0612 | Recall@10: 0.2955
# Alpha: 0.26 | Precision@10: 0.0612 | Recall@10: 0.2954
# Alpha: 0.27 | Precision@10: 0.0613 | Recall@10: 0.2955
# Alpha: 0.28 | Precision@10: 0.0612 | Recall@10: 0.2954
# Alpha: 0.29 | Precision@10: 0.0612 | Recall@10: 0.2951
# Alpha: 0.3 | Precision@10: 0.0611 | Recall@10: 0.2950

# %%
best_alpha = 0.24

full_hybrid_prediction = (best_alpha * full_item_prediction) + ((1 - best_alpha) * full_user_prediction)

# 4. Build the final submission
sample_submission = pd.read_csv(Path.cwd().parent/"data"/"sample_submission.csv")

submission_hybrid = pd.DataFrame()
submission_hybrid["user_id"] = sample_submission["user_id"]
predictions_hybrid = []

i_in_order = interactions["i in order"].to_list()

for u in submission_hybrid["user_id"]:
    
    # 1. Copy the hybrid scores for the user
    u_scores_hybrid = full_hybrid_prediction[u, :].copy()
    
    # Optional but highly recommended: Filter out books the user has already read
    # By setting their score to negative infinity, they will never be recommended
    # u_scores_hybrid[full_data_mtx[u, :] > 0] = -np.inf

    # 2. Get the top 10 highest scoring items 
    # Note: Adding [::-1] reverses the array so your absolute #1 recommendation is listed first!
    top_10_idx = np.argsort(u_scores_hybrid)[-10:][::-1]

    # 3. Map matrix indices back to your original item IDs
    temp_h = []
    for i in top_10_idx:
        # Get the actual item ID based on the index
        actual_item_id = interactions["i"][i_in_order.index(i)]
        temp_h.append(actual_item_id)
    
    # 4. Format as a space-separated string for Kaggle
    predictions_hybrid.append(" ".join(map(str, temp_h)))

# 5. Save the final hybrid submission file
submission_hybrid["recommendation"] = predictions_hybrid
submission_hybrid.to_csv(Path.cwd().parent/"submissions"/"submission_hybrid_full_024.csv", index=False)
print("Hybrid submission saved!")
# Out:
# Hybrid submission saved!

# %%
item_sim_fp16 = item_similarity.astype(np.float16)
item_sim_path = Path.cwd().parent / "data" / "item_similarity.npy"
np.save(item_sim_path, item_sim_fp16)

# %%
data_mtx_int8 = full_data_mtx.astype(np.int8)
np.save(Path.cwd().parent / "data" / "full_data_mtx.npy", data_mtx_int8)
